# %% [markdown]
# # Gesture Control Project

# %% [markdown]
# ## Semester 1 (2018-2019)
# ## Python Code

# %%
import serial 
import time
import pyautogui

ArduinoSerial = serial.Serial('com4',9600) 
time.sleep(2) 

while 1:
    print("Started")
    incoming = str (ArduinoSerial.readline()) 
    print (incoming)
    
    if 'Play/Pause' in incoming:
        pyautogui.typewrite(['space'], 0.2)
        print("Play/Pause")

    if 'Rewind' in incoming:
        pyautogui.hotkey('ctrl', 'left')  
        print("Rewind")

    if 'Forward' in incoming:
        pyautogui.hotkey('ctrl', 'right') 
        print("Forward")

    if 'Vup' in incoming:
        pyautogui.hotkey('ctrl', 'down')
        print("Vup")

    if 'Vdown' in incoming:
        pyautogui.hotkey('ctrl', 'up')
        print("Vdown")

    incoming = "";
# Out:
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vup\r\n'
# Vup
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Rewind\r\n'
# Rewind
# Started
# b'Rewind\r\n'
# Rewind
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Left Locked\r\n'
# Started
# b'Vdown\r\n'
# Vdown
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Right Locked\r\n'
# Started
# b'Forward\r\n'
# Forward
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b'Play/Pause\r\n'
# Play/Pause
# Started
# b''
# Started
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-1-3634041c43d3> in <module>()
#       8 while 1:
#       9     print("Started")
# ---> 10     incoming = str (ArduinoSerial.readline())
#      11     print (incoming)
#      12
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in read(self, size)
#     271             comstat = win32.COMSTAT()
#     272             if not win32.ClearCommError(self._port_handle, ctypes.byref(flags), ctypes.byref(comstat)):
# --> 273                 raise SerialException("ClearCommError failed ({!r})".format(ctypes.WinError()))
#     274             n = min(comstat.cbInQue, size) if self.timeout == 0 else size
#     275             if n > 0:
#
# SerialException: ClearCommError failed (PermissionError(13, 'The device does not recognize the command.', None, 22))
